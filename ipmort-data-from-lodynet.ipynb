# %%
# conding: utf-8
from typing import Container
from bs4 import BeautifulSoup as bs
import urllib.request

# %%
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'
headers = {'User-Agent':user_agent,} 

# https://lodynet.cc/%d9%85%d8%b3%d9%84%d8%b3%d9%84-%d9%81%d9%87%d9%85%d8%aa-%d8%b9%d9%8a%d9%88%d9%86%d9%83-%d8%ad%d9%84%d9%82%d8%a9-177-%d9%85%d8%aa%d8%b1%d8%ac%d9%85%d8%a9/
url = input('Enter Url :')

request = urllib.request.Request(url,None,headers)
response = urllib.request.urlopen(request)

html = response.read()
soup = bs(html, "html.parser")
# print(soup)
# Out:
# Enter Url :https://lodynet.cc/%d9%85%d8%b3%d9%84%d8%b3%d9%84-%d9%81%d9%87%d9%85%d8%aa-%d8%b9%d9%8a%d9%88%d9%86%d9%83-%d8%ad%d9%84%d9%82%d8%a9-177-%d9%85%d8%aa%d8%b1%d8%ac%d9%85%d8%a9/

# %% [markdown]
# # Post Title

# %%
post_title = soup.find_all("div",{"class": "TitleSingle"})
print(post_title[0].h1.text)
# Out:
# مسلسل فهمت عيونك حلقة 177 مترجمة

# %% [markdown]
# # Post Videos

# %%
video_link = soup.find_all("ul",{"class": "ServersList"})
for video_link in video_link:
    for links in video_link.findAll("li"):
        print(links.text)
        print(links.get('data-embed'))
        print()
# Out:
# LoDyTo
# https://www.vidlo.us/embed-pshw56e60yv9.html?st=EK5YWijk9XYRLs5pgcxHYg&e=1632510176
#
# Vid Tv
# https://vedshare.com/embed-czmulwpg3yv9.html?st=6mKU-1TqjDu35M3_tDrwJg&e=1632510176
#
# VidBom
# https://vedbom.org/embed-7f09kbo454uy.html?st=v7DgX1Np4E4OdcXIH7dauQ&e=1632510176
#
# ViD LO
# https://www.vidlo.us/embed-pshw56e60yv9.html?st=EK5YWijk9XYRLs5pgcxHYg&e=1632510176
#
# Govid
# https://govid.cyou/embed-b3an85b7zd3l.html?st=3A18KAzkiUWCayTFouGgpQ&e=1632510176
#
# watchvideo
# https://watchvideo.us/embed-wc6hv282vpua.html?st=PoZe0QWGpl-JIHeaA1I0cw&e=1632510176
#
# ok.ru
# https://www.ok.ru/videoembed/2516156549696?st=-dObyJENh9YZx17v1skb2Q&e=1632510176
#
# LoDyTo1
#  http://s2.lody.to/files/aknns-177/?st=ujTr2F2J_D818MueOcUYMQ&e=1632510176
#
# Ninjastm
# https://ninjastream.to/watch/2KGZ9KRLMA4Bn?st=oKwZnq2Weimf5_iT5jHPdA&e=1632510176
#
# Jaw
# https://jawcloud.co/embed-hqef5xrk2vic.html?st=taGZCjAQdfV8Q43nasParQ&e=1632510176
#
# Fembed
# https://www.fembed.com/v/ejgkpc-l88egjp3?st=Uckg6qyIZt0Q_dS1tQqMkQ&e=1632510176
#
# MosHD
# https://moshahda.net/embed-627mgjit8z6h.html?st=IUL8ospxQr-yM1APr3a9OA&e=1632510176
#
# Yourupload
# https://www.yourupload.com/embed/31e1BQPaCh0G?st=fT2z0YhjNlWLw-Syh512QA&e=1632510176
#
# Uqload
# https://uqload.com/embed-678eu6ahdq2l.html?st=39yx_B9PY_kSTkP1j7oNnA&e=1632510176
#
# Vidoza
# https://vidlox.me/embed-6hugkj42m6p7?st=ZVjyw2wi3639vM_OzIpN2Q&e=1632510176

# %% [markdown]
# # Post Downloads

# %%
download_link = soup.find_all("div",{"class": "DownloadLinks"})
for download_link in download_link:
    for links in download_link.findAll("a"):
        print(links.span.text)
        print(links.get('href'))
        print()
